# %%
# Visualuzation descriptive statistics 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("Ecommerce Customers.csv")

# %%
#without normalized data!!
data_num = data[["Avg. Session Length","Time on App","Time on Website","Length of Membership","Yearly Amount Spent"]]
data_cat = data[["Email","Address"]]

# %%
print(data.shape) #thats why the line plot has this high density
# Out:
# (500, 8)

# %%
#Univariate visual data analysis 

scale_yearly= 1000
plt.plot(data_num["Yearly Amount Spent"]) 

def distplot(x): 
    for i in x:
        return sns.distplot(x[i],kde=False, bins=20) 
    
 

distplot(data_num)

# %%
#bivariate data analysis

#count=[scatter, reg, ]
for i in count():
sns.jointplot(x="Yearly Amount Spent",y = "Length of Membership", data=data_num, kind='reg')
sns.set_context('talk', font_scale=1.4)

# %%
#multivariat visual data anlaysis  def scatter():

sns.pairplot(data_num)



'''def scatter ():
        for i in data_num:
        sns.scatterplot(x=i, y=data_num['Yearly Amount Spent'], data=data_num)
        plt.show()'''
# Out:
# "def scatter ():\n        for i in data_num:\n        sns.scatterplot(x=i, y=data_num['Yearly Amount Spent'], data=data_num)\n        plt.show()"
