# %%
#do the neccesary imports
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.datasets import make_blobs

# %%
data = pd.read_csv("Ecommerce Customers.csv") 
#print(data.head(15))

# %%
#create a blob of 200 data points
'''dataset =make_blobs(data,
                    n_features = 8,
                    centures = 4,
                    cluster_std = 1.6,
                    random_state == 50)
# Out:
#   File "<ipython-input-70-4a6d9f1376ba>", line 3
#     n_features = 8,
#     ^
# IndentationError: unexpected indent

# %%
#data_num = data[["Avg. Session Length","Time on App","Time on Website","Length of Membership","Yearly Amount Spent"]]
#data_cat = data[["Email","Address"]]

x= data.iloc[:,[3,6]].values

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
dendrogram = sch.dendrogram(sch.linkage(x, method='ward'))

# %%
#fitting hierarchical clustering to the dataset 
'''hc = AgglomerativeClustering(n_clusters=3, affinity='euclidean',linkage='ward')
y_hc= hc.fit_predict(data_num)'''

# %%
 #visualize cluster 
'''plt.scatter(data_num[y_hc==0], data_num[y_hc==1], s=100, c='red' ,label='Cluster1')
plt.scatter(data_num[y_hc==1], data_num[y_hc==1], s=100, c='blue', label='Cluster2')
plt.scatter(data_num[y_hc==2], data_num[y_hc==1], s=100, c='green', label='Cluster3')'''
# Out:
# "plt.scatter(data_num[y_hc==0], data_num[y_hc==1], s=100, c='red' ,label='Cluster1')\nplt.scatter(data_num[y_hc==1], data_num[y_hc==1], s=100, c='blue', label='Cluster2')\nplt.scatter(data_num[y_hc==2], data_num[y_hc==1], s=100, c='green', label='Cluster3')"
